# %%
frutas = ["maçã", "banana", "laranja", "uva"]

print(frutas [0])  #maça
print(frutas [3])  #uva
print(frutas [-1]) #uva
print(frutas [-2]) #laranja

print(len (frutas))
# Out:
# maçã
# uva
# uva
# laranja
# 4
