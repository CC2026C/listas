# %%
# lista com números aleatórios

numeros = [17, 2, 4, 25, 18, 30, 41, 15, 8, 10, 53]

print("lista original: ")
print(numeros)

# criação de listas vazias
pares = []
impares = []

# Percorrer a lista e encontrar valores
for numero in numeros:
    if numero % 2 == 0:
        pares.append(numero)

    else :
        impares.append(numero)
print("lista de numeros pares: ")
print(pares)
print()
print("lista de numeors impares: ")
print(impares)
# Out:
# lista original:
# [17, 2, 4, 25, 18, 30, 41, 15, 8, 10, 53]
# lista de numeros pares:
# [2, 4, 18, 30, 8, 10]
#
# lista de numeors impares:
# [17, 25, 41, 15, 53]
